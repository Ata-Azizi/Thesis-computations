# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-                        Action vs Gamma

import time
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize
from cosmoTransitions import pathDeformation as pd


class TwoDimColemanPotential:
    r"""
    Dimensionless potential:
        v(x,y) =
            (x^2 - 1)^2
          + kappa1 (x - 1)
          + rho (y^2 - 1)^2
          + rho*kappa2 (y - 1)
          + gamma x^2 y^2
    """

    def __init__(self, kappa1=0.7, rho=0.5, kappa2=0.6, gamma=0.15):
        self.kappa1 = kappa1
        self.rho = rho
        self.kappa2 = kappa2
        self.gamma = gamma

    def V(self, X):
        X = np.asanyarray(X)
        x, y = X[..., 0], X[..., 1]
        return (
            (x**2 - 1.0)**2
            + self.kappa1 * (x - 1.0)
            + self.rho * (y**2 - 1.0)**2
            + self.rho * self.kappa2 * (y - 1.0)
            + self.gamma * x**2 * y**2
        )

    def dV(self, X):
        X = np.asanyarray(X)
        x, y = X[..., 0], X[..., 1]

        dVdx = 4.0 * x * (x**2 - 1.0) + self.kappa1 + 2.0 * self.gamma * x * y**2
        dVdy = 4.0 * self.rho * y * (y**2 - 1.0) + self.rho * self.kappa2 + 2.0 * self.gamma * x**2 * y

        out = np.empty_like(X)
        out[..., 0] = dVdx
        out[..., 1] = dVdy
        return out

    def hessian_num(self, x, h=1e-5):
        x = np.asarray(x, dtype=float)
        H = np.zeros((2, 2), dtype=float)

        e1 = np.array([1.0, 0.0])
        e2 = np.array([0.0, 1.0])

        H[0, 0] = (self.V(x + h * e1) - 2 * self.V(x) + self.V(x - h * e1)) / h**2
        H[1, 1] = (self.V(x + h * e2) - 2 * self.V(x) + self.V(x - h * e2)) / h**2
        H[0, 1] = H[1, 0] = (
            self.V(x + h * e1 + h * e2)
            - self.V(x + h * e1 - h * e2)
            - self.V(x - h * e1 + h * e2)
            + self.V(x - h * e1 - h * e2)
        ) / (4 * h**2)
        return H


def refine_stationary_point(model, guess):
    res = minimize(model.V, guess, jac=model.dV, method="BFGS", tol=1e-12)
    return res.x, res.fun


def classify_point(model, x):
    H = model.hessian_num(x)
    eigs = np.linalg.eigvalsh(H)
    is_min = np.all(eigs > 1e-7)
    return is_min, eigs


def unique_points(points, tol=1e-4):
    uniq = []
    for p in points:
        if not any(np.linalg.norm(p - q) < tol for q in uniq):
            uniq.append(p)
    return uniq


def find_all_minima(model, xlim=(-2, 2), ylim=(-2, 2), ngrid=17):
    xs = np.linspace(xlim[0], xlim[1], ngrid)
    ys = np.linspace(ylim[0], ylim[1], ngrid)

    candidates = []
    for x0 in xs:
        for y0 in ys:
            try:
                p, _ = refine_stationary_point(model, np.array([x0, y0]))
                is_min, _ = classify_point(model, p)
                if is_min:
                    candidates.append(p)
            except Exception:
                pass

    minima = unique_points(candidates, tol=1e-4)

    result = []
    for p in minima:
        val = model.V(p)
        result.append((p, val))

    result.sort(key=lambda item: item[1])
    return result


def choose_closest_false_vacuum(minima):
    """
    True vacuum = global minimum.
    False vacuum = local minimum with smallest Euclidean distance
    to the true vacuum among the remaining minima.
    """
    if len(minima) < 2:
        raise RuntimeError("Need at least two minima for tunneling.")

    true_vacuum, v_true = minima[0]

    candidates = []
    for p, val in minima[1:]:
        dist = np.linalg.norm(p - true_vacuum)
        candidates.append((dist, p, val))

    candidates.sort(key=lambda t: t[0])
    dist, false_vacuum, v_false = candidates[0]

    return true_vacuum, v_true, false_vacuum, v_false, dist


def same_point(p, q, tol=5e-2):
    return np.linalg.norm(np.asarray(p) - np.asarray(q)) < tol


def scan_action_vs_gamma(
    kappa1=0.7,
    rho=0.5,
    kappa2=0.6,
    gamma_min=0.1,
    gamma_max=0.8,
    n_gamma=36,
    xlim=(-2, 2),
    ylim=(-2, 2),
    ngrid=17
):
    gammas = np.linspace(gamma_min, gamma_max, n_gamma)

    results = []

    for gamma in gammas:
        print(f"\n--- gamma = {gamma:.6f} ---")
        model = TwoDimColemanPotential(
            kappa1=kappa1,
            rho=rho,
            kappa2=kappa2,
            gamma=gamma
        )

        minima = find_all_minima(model, xlim=xlim, ylim=ylim, ngrid=ngrid)
        nmin = len(minima)

        print(f"Number of minima = {nmin}")
        for i, (p, val) in enumerate(minima, start=1):
            print(f"  minimum {i}: ({p[0]: .6f}, {p[1]: .6f}), V = {val: .12f}")

        if nmin < 2:
            print("  Skipping: fewer than two minima.")
            results.append({
                "gamma": gamma,
                "nmin": nmin,
                "action": np.nan,
                "tv": None,
                "fv": None,
                "v_true": np.nan,
                "v_false": np.nan
            })
            continue

        try:
            true_vacuum, v_true, false_vacuum, v_false, dist = choose_closest_false_vacuum(minima)

            print(f"  True vacuum : ({true_vacuum[0]: .6f}, {true_vacuum[1]: .6f}), V = {v_true: .12f}")
            print(f"  False vacuum: ({false_vacuum[0]: .6f}, {false_vacuum[1]: .6f}), V = {v_false: .12f}")
            print(f"  Delta V     = {v_false - v_true: .12f}")
            print(f"  Distance    = {dist: .6f}")

            init_path = [true_vacuum, false_vacuum]
            Y = pd.fullTunneling(init_path, model.V, model.dV)
            action = Y.action

            print(f"  Action      = {action: .12f}")

            results.append({
                "gamma": gamma,
                "nmin": nmin,
                "action": action,
                "tv": np.array(true_vacuum),
                "fv": np.array(false_vacuum),
                "v_true": v_true,
                "v_false": v_false
            })

        except Exception as exc:
            print(f"  Solver failed: {exc}")
            results.append({
                "gamma": gamma,
                "nmin": nmin,
                "action": np.nan,
                "tv": None,
                "fv": None,
                "v_true": np.nan,
                "v_false": np.nan
            })

    return results


def split_into_segments(results, point_tol=5e-2):
    """
    Create a new curve whenever:
      1) number of minima changes, or
      2) chosen true vacuum changes noticeably, or
      3) chosen false vacuum changes noticeably, or
      4) action is NaN / invalid.
    """
    segments = []
    current = []

    prev = None
    for r in results:
        valid = np.isfinite(r["action"]) and (r["tv"] is not None) and (r["fv"] is not None)

        if not valid:
            if current:
                segments.append(current)
                current = []
            prev = None
            continue

        if prev is None:
            current = [r]
            prev = r
            continue

        changed = False

        if r["nmin"] != prev["nmin"]:
            changed = True
        elif not same_point(r["tv"], prev["tv"], tol=point_tol):
            changed = True
        elif not same_point(r["fv"], prev["fv"], tol=point_tol):
            changed = True

        if changed:
            if current:
                segments.append(current)
            current = [r]
        else:
            current.append(r)

        prev = r

    if current:
        segments.append(current)

    return segments


def plot_action_vs_gamma(results):
    segments = split_into_segments(results, point_tol=5e-2)

    plt.figure(figsize=(9, 6))

    for i, seg in enumerate(segments, start=1):
        gammas = [r["gamma"] for r in seg]
        actions = [r["action"] for r in seg]
        nmin = seg[0]["nmin"]

        label = f"Segment {i}: {nmin} minima"
        plt.plot(gammas, actions, marker='o', linewidth=2, label=label)

    plt.xlabel(r"$\gamma$")
    plt.ylabel("B")
  #  plt.title(r"Action vs $\gamma$ for fixed $\kappa_1=0.7,\ \rho=0.5,\ \kappa_2=0.6$")
    plt.grid(True, alpha=0.3)
    plt.legend(fontsize='small')
    plt.tight_layout()
    
    plt.show()


def main():
    start = time.perf_counter()

    results = scan_action_vs_gamma(
        kappa1=0.7,
        rho=0.5,
        kappa2=0.6,
        gamma_min=0.1,
        gamma_max=0.8,
        n_gamma=36,   # increase if you want smoother curves
        xlim=(-2, 2),
        ylim=(-2, 2),
        ngrid=17
    )

    print("\n================ SUMMARY ================")
    for r in results:
        if np.isfinite(r["action"]):
            print(
                f"gamma={r['gamma']:.6f}, "
                f"nmin={r['nmin']}, "
                f"action={r['action']:.10f}, "
                f"TV=({r['tv'][0]:.6f},{r['tv'][1]:.6f}), "
                f"FV=({r['fv'][0]:.6f},{r['fv'][1]:.6f})"
            )
        else:
            print(
                f"gamma={r['gamma']:.6f}, "
                f"nmin={r['nmin']}, action=NaN"
            )

    plot_action_vs_gamma(results)

    end = time.perf_counter()
    print(f"\nRuntime: {end - start:.6f} seconds")


if __name__ == "__main__":
    main()
# Out:
# --- gamma = 0.100000 ---
# Number of minima = 4
#   minimum 1: (-1.055464, -1.017827), V = -1.915121244937
#   minimum 2: (-1.062655,  0.841976), V = -1.352146928799
#   minimum 3: ( 0.862275, -1.034706), V = -0.558940745109
#   minimum 4: ( 0.872920,  0.866414), V =  0.015899700590
#   True vacuum : (-1.055464, -1.017827), V = -1.915121244937
#   False vacuum: (-1.062655,  0.841976), V = -1.352146928799
#   Delta V     =  0.562974316137
#   Distance    =  1.859817
# Path deformation converged. 9 steps. fRatio = 1.10578e-02
# Path deformation converged. 1 steps. fRatio = 6.30112e-04
#   Action      =  59.720168228011
#
# --- gamma = 0.120000 ---
# Number of minima = 4
#   minimum 1: (-1.051415, -1.008041), V = -1.892348998518
#   minimum 2: (-1.060207,  0.826866), V = -1.336457303610
#   minimum 3: ( 0.855555, -1.028588), V = -0.543237671663
#   minimum 4: ( 0.868596,  0.856991), V =  0.027159643833
#   True vacuum : (-1.051415, -1.008041), V = -1.892348998518
#   False vacuum: (-1.060207,  0.826866), V = -1.336457303610
#   Delta V     =  0.555891694908
#   Distance    =  1.834928
# Path deformation converged. 9 steps. fRatio = 1.30418e-02
# Path deformation converged. 1 steps. fRatio = 9.27700e-04
#   Action      =  53.765368897313
#
# --- gamma = 0.140000 ---
# Number of minima = 4
#   minimum 1: (-1.047520, -0.998314), V = -1.870181429090
#   minimum 2: (-1.057979,  0.811443), V = -1.321402908734
#   minimum 3: ( 0.848910, -1.022638), V = -0.527958292623
#   minimum 4: ( 0.864448,  0.847591), V =  0.038068062017
#   True vacuum : (-1.047520, -0.998314), V = -1.870181429090
#   False vacuum: (-1.057979,  0.811443), V = -1.321402908734
#   Delta V     =  0.548778520356
#   Distance    =  1.809787
# Path deformation converged. 9 steps. fRatio = 1.50259e-02
# Path deformation converged. 1 steps. fRatio = 1.30249e-03
#   Action      =  47.845770044464
#
# --- gamma = 0.160000 ---
# Number of minima = 4
#   minimum 1: (-1.043776, -0.988640), V = -1.848598446867
#   minimum 2: (-1.055973,  0.795652), V = -1.306974340661
#   minimum 3: ( 0.842333, -1.016853), V = -0.513086681422
#   minimum 4: ( 0.860475,  0.838199), V =  0.048637554457
#   True vacuum : (-1.043776, -0.988640), V = -1.848598446867
#   False vacuum: (-1.055973,  0.795652), V = -1.306974340661
#   Delta V     =  0.541624106205
#   Distance    =  1.784334
# Path deformation converged. 9 steps. fRatio = 1.70286e-02
# Path deformation converged. 1 steps. fRatio = 1.75655e-03
#   Action      =  42.548700538579
#
# --- gamma = 0.180000 ---
# Number of minima = 4
#   minimum 1: (-1.040182, -0.979010), V = -1.827581059163
#   minimum 2: (-1.054195,  0.779431), V = -1.293164175127
#   minimum 3: ( 0.835818, -1.011231), V = -0.498607751859
#   minimum 4: ( 0.856680,  0.828803), V =  0.058879915930
#   True vacuum : (-1.040182, -0.979010), V = -1.827581059163
#   False vacuum: (-1.054195,  0.779431), V = -1.293164175127
#   Delta V     =  0.534416884036
#   Distance    =  1.758497
# Path deformation converged. 9 steps. fRatio = 1.91222e-02
# Path deformation converged. 1 steps. fRatio = 2.26672e-03
#   Action      =  37.817225342777
#
# --- gamma = 0.200000 ---
# Number of minima = 4
#   minimum 1: (-1.036736, -0.969416), V = -1.807111310339
#   minimum 2: (-1.052652,  0.762703), V = -1.279967114395
#   minimum 3: ( 0.829359, -1.005769), V = -0.484507209128
#   minimum 4: ( 0.853064,  0.819385), V =  0.068806168473
#   True vacuum : (-1.036736, -0.969416), V = -1.807111310339
#   False vacuum: (-1.052652,  0.762703), V = -1.279967114395
#   Delta V     =  0.527144195943
#   Distance    =  1.732192
# Path deformation converged. 11 steps. fRatio = 1.68170e-02
# Path deformation converged. 1 steps. fRatio = 1.24826e-02
#   Action      =  33.339768441623
#
# --- gamma = 0.220000 ---
# Number of minima = 4
#   minimum 1: (-1.033437, -0.959852), V = -1.787172226580
#   minimum 2: (-1.051351,  0.745376), V = -1.267380201587
#   minimum 3: ( 0.822951, -1.000468), V = -0.470771504876
#   minimum 4: ( 0.849629,  0.809931), V =  0.078426587669
#   True vacuum : (-1.033437, -0.959852), V = -1.787172226580
#   False vacuum: (-1.051351,  0.745376), V = -1.267380201587
#   Delta V     =  0.519792024993
#   Distance    =  1.705322
# Path deformation converged. 11 steps. fRatio = 1.88053e-02
# Path deformation converged. 1 steps. fRatio = 1.41733e-02
#   Action      =  29.105376504661
#
# --- gamma = 0.240000 ---
# Number of minima = 4
#   minimum 1: (-1.030284, -0.950309), V = -1.767747765140
#   minimum 2: (-1.050303,  0.727334), V = -1.255403129915
#   minimum 3: ( 0.816586, -0.995324), V = -0.457387796042
#   minimum 4: ( 0.846378,  0.800421), V =  0.087750723215
#   True vacuum : (-1.030284, -0.950309), V = -1.767747765140
#   False vacuum: (-1.050303,  0.727334), V = -1.255403129915
#   Delta V     =  0.512344635225
#   Distance    =  1.677762
# Path deformation converged. 12 steps. fRatio = 1.44387e-02
# Path deformation converged. 1 steps. fRatio = 9.87201e-03
#   Action      =  25.107346892019
#
# --- gamma = 0.260000 ---
# Number of minima = 4
#   minimum 1: (-1.027276, -0.940779), V = -1.748822767701
#   minimum 2: (-1.049523,  0.708431), V = -1.244038692256
#   minimum 3: ( 0.810259, -0.990337), V = -0.444343907209
#   minimum 4: ( 0.843316,  0.790835), V =  0.096787413447
#   True vacuum : (-1.027276, -0.940779), V = -1.748822767701
#   False vacuum: (-1.049523,  0.708431), V = -1.244038692256
#   Delta V     =  0.504784075444
#   Distance    =  1.649361
# Path deformation converged. 12 steps. fRatio = 1.64916e-02
# Path deformation converged. 1 steps. fRatio = 1.17880e-02
#   Action      =  21.413126910039
#
# --- gamma = 0.280000 ---
# Number of minima = 4
#   minimum 1: (-1.024411, -0.931255), V = -1.730382917556
#   minimum 2: (-1.049029,  0.688475), V = -1.233293448617
#   minimum 3: ( 0.803963, -0.985508), V = -0.431628296298
#   minimum 4: ( 0.840446,  0.781152), V =  0.105544793294
#   True vacuum : (-1.024411, -0.931255), V = -1.730382917556
#   False vacuum: (-1.049029,  0.688475), V = -1.233293448617
#   Delta V     =  0.497089468939
#   Distance    =  1.619917
# Path deformation converged. 12 steps. fRatio = 1.92144e-02
# Path deformation converged. 1 steps. fRatio = 1.42013e-02
#   Action      =  17.999468160026
#
# --- gamma = 0.300000 ---
# Number of minima = 4
#   minimum 1: (-1.021689, -0.921729), V = -1.712414700346
#   minimum 2: (-1.048845,  0.667201), V = -1.223178751915
#   minimum 3: ( 0.797691, -0.980835), V = -0.419230023424
#   minimum 4: ( 0.837775,  0.771346), V =  0.114030294856
#   True vacuum : (-1.021689, -0.921729), V = -1.712414700346
#   False vacuum: (-1.048845,  0.667201), V = -1.223178751915
#   Delta V     =  0.489235948431
#   Distance    =  1.589162
# Path deformation converged. 13 steps. fRatio = 1.26244e-02
# Path deformation converged. 1 steps. fRatio = 8.74883e-03
#   Action      =  14.826642965416
#
# --- gamma = 0.320000 ---
# Number of minima = 4
#   minimum 1: (-1.019109, -0.912191), V = -1.694905368084
#   minimum 2: (-1.049009,  0.644227), V = -1.213712406333
#   minimum 3: ( 0.791436, -0.976319), V = -0.407138722787
#   minimum 4: ( 0.835310,  0.761390), V =  0.122250639513
#   True vacuum : (-1.019109, -0.912191), V = -1.694905368084
#   False vacuum: (-1.049009,  0.644227), V = -1.213712406333
#   Delta V     =  0.481192961751
#   Distance    =  1.556705
# Path deformation converged. 13 steps. fRatio = 1.61641e-02
# Path deformation converged. 1 steps. fRatio = 1.09823e-02
#   Action      =  11.950590696311
#
# --- gamma = 0.340000 ---
# Number of minima = 4
#   minimum 1: (-1.016672, -0.902634), V = -1.677842906263
#   minimum 2: (-1.049574,  0.618961), V = -1.204921549951
#   minimum 3: ( 0.785190, -0.971961), V = -0.395344577530
#   minimum 4: ( 0.833059,  0.751251), V =  0.130211819978
#   True vacuum : (-1.016672, -0.902634), V = -1.677842906263
#   False vacuum: (-1.049574,  0.618961), V = -1.204921549951
#   Delta V     =  0.472921356313
#   Distance    =  1.521951
# Path deformation converged. 10 steps. fRatio = 6.56851e-03
# Path deformation converged. 1 steps. fRatio = 5.42961e-03
#   Action      =  9.262366209162
#
# --- gamma = 0.360000 ---
# Number of minima = 4
#   minimum 1: (-1.014378, -0.893049), V = -1.661216003822
#   minimum 2: (-1.050632,  0.590380), V = -1.196848228999
#   minimum 3: ( 0.778945, -0.967763), V = -0.383838297500
#   minimum 4: ( 0.831031,  0.740892), V =  0.137919070063
#   True vacuum : (-1.014378, -0.893049), V = -1.661216003822
#   False vacuum: (-1.050632,  0.590380), V = -1.196848228999
#   Delta V     =  0.464367774823
#   Distance    =  1.483872
# Path deformation converged. 10 steps. fRatio = 1.24679e-02
# Path deformation converged. 1 steps. fRatio = 4.48137e-03
#   Action      =  6.718109470640
#
# --- gamma = 0.380000 ---
# Number of minima = 4
#   minimum 1: (-1.012226, -0.883428), V = -1.645014025795
#   minimum 2: (-1.052367,  0.556381), V = -1.189562159849
#   minimum 3: ( 0.772693, -0.963725), V = -0.372611099937
#   minimum 4: ( 0.829239,  0.730270), V =  0.145376819025
#   True vacuum : (-1.012226, -0.883428), V = -1.645014025795
#   False vacuum: (-1.052367,  0.556381), V = -1.189562159849
#   Delta V     =  0.455451865946
#   Distance    =  1.440368
# Path deformation converged. 13 steps. fRatio = 1.34124e-02
# Path deformation converged. 1 steps. fRatio = 1.60711e-02
#   Action      =  4.310510505580
#
# --- gamma = 0.400000 ---
# Number of minima = 4
#   minimum 1: (-1.010217, -0.873760), V = -1.629226988456
#   minimum 2: (-1.055303,  0.510712), V = -1.183200962867
#   minimum 3: ( 0.766423, -0.959850), V = -0.361654693128
#   minimum 4: ( 0.827697,  0.719334), V =  0.152588625951
#   True vacuum : (-1.010217, -0.873760), V = -1.629226988456
#   False vacuum: (-1.055303,  0.510712), V = -1.183200962867
#   Delta V     =  0.446026025589
#   Distance    =  1.385206
# Path deformation converged. 14 steps. fRatio = 1.51643e-02
# Path deformation converged. 1 steps. fRatio = 1.78854e-02
#   Action      =  1.959028044836
#
# --- gamma = 0.420000 ---
# Number of minima = 3
#   minimum 1: (-1.008352, -0.864036), V = -1.613845536800
#   minimum 2: ( 0.760126, -0.956142), V = -0.350961263179
#   minimum 3: ( 0.826421,  0.708021), V =  0.159557087542
#   True vacuum : (-1.008352, -0.864036), V = -1.613845536800
#   False vacuum: ( 0.760126, -0.956142), V = -0.350961263179
#   Delta V     =  1.262884273621
#   Distance    =  1.770874
# Path deformation converged. 28 steps. fRatio = 1.90123e-02
# Path deformation converged. 1 steps. fRatio = 7.33086e-02
#   Action      =  17.070645391000
#
# --- gamma = 0.440000 ---
# Number of minima = 3
#   minimum 1: (-1.006630, -0.854248), V = -1.598860924195
#   minimum 2: ( 0.753790, -0.952604), V = -0.340523464085
#   minimum 3: ( 0.825433,  0.696256), V =  0.166283709322
#   True vacuum : (-1.006630, -0.854248), V = -1.598860924195
#   False vacuum: ( 0.753790, -0.952604), V = -0.340523464085
#   Delta V     =  1.258337460110
#   Distance    =  1.763166
# Path deformation converged. 29 steps. fRatio = 1.90489e-02
# Path deformation converged. 1 steps. fRatio = 7.40386e-02
#   Action      =  16.126089665139
#
# --- gamma = 0.460000 ---
# Number of minima = 3
#   minimum 1: (-1.005054, -0.844383), V = -1.584264994055
#   minimum 2: ( 0.747404, -0.949241), V = -0.330334411422
#   minimum 3: ( 0.824759,  0.683944), V =  0.172768724797
#   True vacuum : (-1.005054, -0.844383), V = -1.584264994055
#   False vacuum: ( 0.747404, -0.949241), V = -0.330334411422
#   Delta V     =  1.253930582633
#   Distance    =  1.755592
# Path deformation converged. 32 steps. fRatio = 1.65999e-02
# Path deformation converged. 1 steps. fRatio = 7.60230e-02
#   Action      =  15.210539428301
#
# --- gamma = 0.480000 ---
# Number of minima = 3
#   minimum 1: (-1.003624, -0.834432), V = -1.570050163371
#   minimum 2: ( 0.740953, -0.946059), V = -0.320387680091
#   minimum 3: ( 0.824431,  0.670963), V =  0.179010837663
#   True vacuum : (-1.003624, -0.834432), V = -1.570050163371
#   False vacuum: ( 0.740953, -0.946059), V = -0.320387680091
#   Delta V     =  1.249662483280
#   Distance    =  1.748145
# Path deformation converged. 32 steps. fRatio = 1.70679e-02
# Path deformation converged. 1 steps. fRatio = 7.70755e-02
#   Action      =  14.324660674387
#
# --- gamma = 0.500000 ---
# Number of minima = 3
#   minimum 1: (-1.002342, -0.824384), V = -1.556209407935
#   minimum 2: ( 0.734422, -0.943063), V = -0.310677306725
#   minimum 3: ( 0.824491,  0.657153), V =  0.185006845013
#   True vacuum : (-1.002342, -0.824384), V = -1.556209407935
#   False vacuum: ( 0.734422, -0.943063), V = -0.310677306725
#   Delta V     =  1.245532101210
#   Distance    =  1.740813
# Path deformation converged. 33 steps. fRatio = 1.85640e-02
# Path deformation converged. 1 steps. fRatio = 7.45389e-02
#   Action      =  13.461051722679
#
# --- gamma = 0.520000 ---
# Number of minima = 3
#   minimum 1: (-1.001208, -0.814228), V = -1.542736249100
#   minimum 2: ( 0.727793, -0.940263), V = -0.301197797612
#   minimum 3: ( 0.824995,  0.642294), V =  0.190751066314
#   True vacuum : (-1.001208, -0.814228), V = -1.542736249100
#   False vacuum: ( 0.727793, -0.940263), V = -0.301197797612
#   Delta V     =  1.241538451488
#   Distance    =  1.733588
# Path deformation converged. 33 steps. fRatio = 1.85750e-02
# Path deformation converged. 1 steps. fRatio = 7.54117e-02
#   Action      =  12.619664575467
#
# --- gamma = 0.540000 ---
# Number of minima = 3
#   minimum 1: (-1.000225, -0.803950), V = -1.529624741854
#   minimum 2: ( 0.721046, -0.937668), V = -0.291944143283
#   minimum 3: ( 0.826022,  0.626068), V =  0.196234433118
#   True vacuum : (-1.000225, -0.803950), V = -1.529624741854
#   False vacuum: ( 0.721046, -0.937668), V = -0.291944143283
#   Delta V     =  1.237680598571
#   Distance    =  1.726457
# Path deformation converged. 36 steps. fRatio = 1.56243e-02
# Path deformation converged. 1 steps. fRatio = 7.75197e-02
#   Action      =  11.813090423451
#
# --- gamma = 0.560000 ---
# Number of minima = 3
#   minimum 1: (-0.999394, -0.793539), V = -1.516869464019
#   minimum 2: ( 0.714158, -0.935289), V = -0.282911841403
#   minimum 3: ( 0.827687,  0.607985), V =  0.201442931158
#   True vacuum : (-0.999394, -0.793539), V = -1.516869464019
#   False vacuum: ( 0.714158, -0.935289), V = -0.282911841403
#   Delta V     =  1.233957622616
#   Distance    =  1.719405
# Path deformation converged. 24 steps. fRatio = 1.92469e-02
# Path deformation converged. 1 steps. fRatio = 8.36103e-02
#   Action      =  11.003904565062
#
# --- gamma = 0.580000 ---
# Number of minima = 3
#   minimum 1: (-0.998718, -0.782983), V = -1.504465506301
#   minimum 2: ( 0.707102, -0.933141), V = -0.274096930222
#   minimum 3: ( 0.830185,  0.587208), V =  0.206354643956
#   True vacuum : (-0.998718, -0.782983), V = -1.504465506301
#   False vacuum: ( 0.707102, -0.933141), V = -0.274096930222
#   Delta V     =  1.230368576079
#   Distance    =  1.712416
# Path deformation converged. 22 steps. fRatio = 1.92051e-02
# Path deformation converged. 1 steps. fRatio = 8.76896e-02
#   Action      =  10.277484396612
#
# --- gamma = 0.600000 ---
# Number of minima = 3
#   minimum 1: (-0.998197, -0.772266), V = -1.492408462898
#   minimum 2: ( 0.699845, -0.931239), V = -0.265496035829
#   minimum 3: ( 0.833890,  0.562045), V =  0.210933154878
#   True vacuum : (-0.998197, -0.772266), V = -1.492408462898
#   False vacuum: ( 0.699845, -0.931239), V = -0.265496035829
#   Delta V     =  1.226912427069
#   Distance    =  1.705467
# Path deformation converged. 24 steps. fRatio = 1.93636e-02
# Path deformation converged. 15 steps. fRatio = 1.64720e-02
# Path deformation converged. 1 steps. fRatio = 2.12780e-02
#   Action      =  9.491565583901
#
# --- gamma = 0.620000 ---
# Number of minima = 3
#   minimum 1: (-0.997835, -0.761376), V = -1.480694422299
#   minimum 2: ( 0.692348, -0.929604), V = -0.257106437900
#   minimum 3: ( 0.839823,  0.527686), V =  0.215107649850
#   True vacuum : (-0.997835, -0.761376), V = -1.480694422299
#   False vacuum: ( 0.692348, -0.929604), V = -0.257106437900
#   Delta V     =  1.223587984399
#   Distance    =  1.698535
# Path deformation converged. 25 steps. fRatio = 1.92117e-02
# Path deformation converged. 15 steps. fRatio = 1.66309e-02
# Path deformation converged. 1 steps. fRatio = 2.05163e-02
#   Action      =  8.755349550337
#
# --- gamma = 0.640000 ---
# Number of minima = 2
#   minimum 1: (-0.997633, -0.750298), V = -1.469319957833
#   minimum 2: ( 0.684565, -0.928262), V = -0.248926160898
#   True vacuum : (-0.997633, -0.750298), V = -1.469319957833
#   False vacuum: ( 0.684565, -0.928262), V = -0.248926160898
#   Delta V     =  1.220393796935
#   Distance    =  1.691585
# Path deformation converged. 23 steps. fRatio = 1.76709e-02
# Path deformation converged. 17 steps. fRatio = 1.88423e-02
# Path deformation converged. 1 steps. fRatio = 1.99306e-02
#   Action      =  8.030911198241
#
# --- gamma = 0.660000 ---
# Number of minima = 2
#   minimum 1: (-0.997594, -0.739016), V = -1.458282117426
#   minimum 2: ( 0.676435, -0.927242), V = -0.240954101372
#   True vacuum : (-0.997594, -0.739016), V = -1.458282117426
#   False vacuum: ( 0.676435, -0.927242), V = -0.240954101372
#   Delta V     =  1.217328016054
#   Distance    =  1.684578
# Path deformation converged. 28 steps. fRatio = 1.65930e-02
# Path deformation converged. 16 steps. fRatio = 1.47047e-02
# Path deformation converged. 1 steps. fRatio = 1.86743e-02
#   Action      =  7.333018284959
#
# --- gamma = 0.680000 ---
# Number of minima = 2
#   minimum 1: (-0.997720, -0.727515), V = -1.447578411902
#   minimum 2: ( 0.667884, -0.926584), V = -0.233190208127
#   True vacuum : (-0.997720, -0.727515), V = -1.447578411902
#   False vacuum: ( 0.667884, -0.926584), V = -0.233190208127
#   Delta V     =  1.214388203775
#   Distance    =  1.677458
# Path deformation converged. 35 steps. fRatio = 1.97141e-02
# Path deformation converged. 16 steps. fRatio = 1.66484e-02
# Path deformation converged. 1 steps. fRatio = 1.80709e-02
#   Action      =  6.602127277209
#
# --- gamma = 0.700000 ---
# Number of minima = 2
#   minimum 1: (-0.998013, -0.715780), V = -1.437206801016
#   minimum 2: ( 0.658813, -0.926339), V = -0.225635742873
#   True vacuum : (-0.998013, -0.715780), V = -1.437206801016
#   False vacuum: ( 0.658813, -0.926339), V = -0.225635742873
#   Delta V     =  1.211571058143
#   Distance    =  1.670151
# Path deformation converged. 36 steps. fRatio = 1.79172e-02
# Path deformation converged. 19 steps. fRatio = 1.83637e-02
# Path deformation converged. 1 steps. fRatio = 1.88375e-02
#   Action      =  5.893514610212
#
# --- gamma = 0.720000 ---
# Number of minima = 2
#   minimum 1: (-0.998474, -0.703794), V = -1.427165676232
#   minimum 2: ( 0.649090, -0.926573), V = -0.218293669047
#   True vacuum : (-0.998474, -0.703794), V = -1.427165676232
#   False vacuum: ( 0.649090, -0.926573), V = -0.218293669047
#   Delta V     =  1.208872007184
#   Distance    =  1.662558
# Path deformation converged. 36 steps. fRatio = 1.99256e-02
# Path deformation converged. 17 steps. fRatio = 1.86030e-02
# Path deformation converged. 1 steps. fRatio = 2.08298e-02
#   Action      =  5.202240907548
#
# --- gamma = 0.740000 ---
# Number of minima = 2
#   minimum 1: (-0.999105, -0.691542), V = -1.417453839038
#   minimum 2: ( 0.638531, -0.927379), V = -0.211169256518
#   True vacuum : (-0.999105, -0.691542), V = -1.417453839038
#   False vacuum: ( 0.638531, -0.927379), V = -0.211169256518
#   Delta V     =  1.206284582519
#   Distance    =  1.654530
# Path deformation converged. 39 steps. fRatio = 1.99228e-02
# Path deformation converged. 13 steps. fRatio = 1.78196e-02
# Path deformation converged. 1 steps. fRatio = 1.85120e-02
#   Action      =  4.494855083000
#
# --- gamma = 0.760000 ---
# Number of minima = 2
#   minimum 1: (-0.999908, -0.679007), V = -1.408070473373
#   minimum 2: ( 0.626857, -0.928892), V = -0.204271076910
#   True vacuum : (-0.999908, -0.679007), V = -1.408070473373
#   False vacuum: ( 0.626857, -0.928892), V = -0.204271076910
#   Delta V     =  1.203799396462
#   Distance    =  1.645846
# Path deformation converged. 32 steps. fRatio = 1.81927e-02
# Path deformation converged. 15 steps. fRatio = 1.89402e-02
# Path deformation converged. 1 steps. fRatio = 3.56684e-02
#   Action      =  3.793518468240
#
# --- gamma = 0.780000 ---
# Number of minima = 2
#   minimum 1: (-1.000884, -0.666174), V = -1.399015110454
#   minimum 2: ( 0.613630, -0.931321), V = -0.197612776734
#   True vacuum : (-1.000884, -0.666174), V = -1.399015110454
#   False vacuum: ( 0.613630, -0.931321), V = -0.197612776734
#   Delta V     =  1.201402333720
#   Distance    =  1.636141
# Path deformation converged. 37 steps. fRatio = 1.64083e-02
# Path deformation converged. 18 steps. fRatio = 1.52611e-02
# Path deformation converged. 1 steps. fRatio = 1.71450e-02
#   Action      =  3.076757836909
#
# --- gamma = 0.800000 ---
# Number of minima = 2
#   minimum 1: (-1.002031, -0.653028), V = -1.390287584040
#   minimum 2: ( 0.598056, -0.935032), V = -0.191216626252
#   True vacuum : (-1.002031, -0.653028), V = -1.390287584040
#   False vacuum: ( 0.598056, -0.935032), V = -0.191216626252
#   Delta V     =  1.199070957789
#   Distance    =  1.624748
# Path deformation converged. 29 steps. fRatio = 1.65402e-02
# Path deformation converged. 16 steps. fRatio = 1.89166e-02
# Path deformation converged. 1 steps. fRatio = 4.22022e-02
#   Action      =  2.337817786742
#
# ================ SUMMARY ================
# gamma=0.100000, nmin=4, action=59.7201682280, TV=(-1.055464,-1.017827), FV=(-1.062655,0.841976)
# gamma=0.120000, nmin=4, action=53.7653688973, TV=(-1.051415,-1.008041), FV=(-1.060207,0.826866)
# gamma=0.140000, nmin=4, action=47.8457700445, TV=(-1.047520,-0.998314), FV=(-1.057979,0.811443)
# gamma=0.160000, nmin=4, action=42.5487005386, TV=(-1.043776,-0.988640), FV=(-1.055973,0.795652)
# gamma=0.180000, nmin=4, action=37.8172253428, TV=(-1.040182,-0.979010), FV=(-1.054195,0.779431)
# gamma=0.200000, nmin=4, action=33.3397684416, TV=(-1.036736,-0.969416), FV=(-1.052652,0.762703)
# gamma=0.220000, nmin=4, action=29.1053765047, TV=(-1.033437,-0.959852), FV=(-1.051351,0.745376)
# gamma=0.240000, nmin=4, action=25.1073468920, TV=(-1.030284,-0.950309), FV=(-1.050303,0.727334)
# gamma=0.260000, nmin=4, action=21.4131269100, TV=(-1.027276,-0.940779), FV=(-1.049523,0.708431)
# gamma=0.280000, nmin=4, action=17.9994681600, TV=(-1.024411,-0.931255), FV=(-1.049029,0.688475)
# gamma=0.300000, nmin=4, action=14.8266429654, TV=(-1.021689,-0.921729), FV=(-1.048845,0.667201)
# gamma=0.320000, nmin=4, action=11.9505906963, TV=(-1.019109,-0.912191), FV=(-1.049009,0.644227)
# gamma=0.340000, nmin=4, action=9.2623662092, TV=(-1.016672,-0.902634), FV=(-1.049574,0.618961)
# gamma=0.360000, nmin=4, action=6.7181094706, TV=(-1.014378,-0.893049), FV=(-1.050632,0.590380)
# gamma=0.380000, nmin=4, action=4.3105105056, TV=(-1.012226,-0.883428), FV=(-1.052367,0.556381)
# gamma=0.400000, nmin=4, action=1.9590280448, TV=(-1.010217,-0.873760), FV=(-1.055303,0.510712)
# gamma=0.420000, nmin=3, action=17.0706453910, TV=(-1.008352,-0.864036), FV=(0.760126,-0.956142)
# gamma=0.440000, nmin=3, action=16.1260896651, TV=(-1.006630,-0.854248), FV=(0.753790,-0.952604)
# gamma=0.460000, nmin=3, action=15.2105394283, TV=(-1.005054,-0.844383), FV=(0.747404,-0.949241)
# gamma=0.480000, nmin=3, action=14.3246606744, TV=(-1.003624,-0.834432), FV=(0.740953,-0.946059)
# gamma=0.500000, nmin=3, action=13.4610517227, TV=(-1.002342,-0.824384), FV=(0.734422,-0.943063)
# gamma=0.520000, nmin=3, action=12.6196645755, TV=(-1.001208,-0.814228), FV=(0.727793,-0.940263)
# gamma=0.540000, nmin=3, action=11.8130904235, TV=(-1.000225,-0.803950), FV=(0.721046,-0.937668)
# gamma=0.560000, nmin=3, action=11.0039045651, TV=(-0.999394,-0.793539), FV=(0.714158,-0.935289)
# gamma=0.580000, nmin=3, action=10.2774843966, TV=(-0.998718,-0.782983), FV=(0.707102,-0.933141)
# gamma=0.600000, nmin=3, action=9.4915655839, TV=(-0.998197,-0.772266), FV=(0.699845,-0.931239)
# gamma=0.620000, nmin=3, action=8.7553495503, TV=(-0.997835,-0.761376), FV=(0.692348,-0.929604)
# gamma=0.640000, nmin=2, action=8.0309111982, TV=(-0.997633,-0.750298), FV=(0.684565,-0.928262)
# gamma=0.660000, nmin=2, action=7.3330182850, TV=(-0.997594,-0.739016), FV=(0.676435,-0.927242)
# gamma=0.680000, nmin=2, action=6.6021272772, TV=(-0.997720,-0.727515), FV=(0.667884,-0.926584)
# gamma=0.700000, nmin=2, action=5.8935146102, TV=(-0.998013,-0.715780), FV=(0.658813,-0.926339)
# gamma=0.720000, nmin=2, action=5.2022409075, TV=(-0.998474,-0.703794), FV=(0.649090,-0.926573)
# gamma=0.740000, nmin=2, action=4.4948550830, TV=(-0.999105,-0.691542), FV=(0.638531,-0.927379)
# gamma=0.760000, nmin=2, action=3.7935184682, TV=(-0.999908,-0.679007), FV=(0.626857,-0.928892)
# gamma=0.780000, nmin=2, action=3.0767578369, TV=(-1.000884,-0.666174), FV=(0.613630,-0.931321)
# gamma=0.800000, nmin=2, action=2.3378177867, TV=(-1.002031,-0.653028), FV=(0.598056,-0.935032)
# Runtime: 32.078942 seconds
