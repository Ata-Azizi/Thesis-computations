# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-              Action vs Kappa2

import time
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize
from cosmoTransitions import pathDeformation as pd


class TwoDimColemanPotential:
    r"""
    Dimensionless potential:
        v(x,y) =
            (x^2 - 1)^2
          + kappa1 (x - 1)
          + rho (y^2 - 1)^2
          + rho*kappa2 (y - 1)
          + gamma x^2 y^2
    """

    def __init__(self, kappa1=0.7, rho=0.5, kappa2=0.6, gamma=0.2):
        self.kappa1 = kappa1
        self.rho = rho
        self.kappa2 = kappa2
        self.gamma = gamma

    def V(self, X):
        X = np.asanyarray(X)
        x, y = X[..., 0], X[..., 1]
        return (
            (x**2 - 1.0)**2
            + self.kappa1 * (x - 1.0)
            + self.rho * (y**2 - 1.0)**2
            + self.rho * self.kappa2 * (y - 1.0)
            + self.gamma * x**2 * y**2
        )

    def dV(self, X):
        X = np.asanyarray(X)
        x, y = X[..., 0], X[..., 1]

        dVdx = 4.0 * x * (x**2 - 1.0) + self.kappa1 + 2.0 * self.gamma * x * y**2
        dVdy = 4.0 * self.rho * y * (y**2 - 1.0) + self.rho * self.kappa2 + 2.0 * self.gamma * x**2 * y

        out = np.empty_like(X)
        out[..., 0] = dVdx
        out[..., 1] = dVdy
        return out

    def hessian_num(self, x, h=1e-5):
        x = np.asarray(x, dtype=float)
        H = np.zeros((2, 2), dtype=float)

        e1 = np.array([1.0, 0.0])
        e2 = np.array([0.0, 1.0])

        H[0, 0] = (self.V(x + h * e1) - 2 * self.V(x) + self.V(x - h * e1)) / h**2
        H[1, 1] = (self.V(x + h * e2) - 2 * self.V(x) + self.V(x - h * e2)) / h**2
        H[0, 1] = H[1, 0] = (
            self.V(x + h * e1 + h * e2)
            - self.V(x + h * e1 - h * e2)
            - self.V(x - h * e1 + h * e2)
            + self.V(x - h * e1 - h * e2)
        ) / (4 * h**2)
        return H


def refine_stationary_point(model, guess):
    res = minimize(model.V, guess, jac=model.dV, method="BFGS", tol=1e-12)
    return res.x, res.fun


def classify_point(model, x):
    H = model.hessian_num(x)
    eigs = np.linalg.eigvalsh(H)
    is_min = np.all(eigs > 1e-7)
    return is_min, eigs


def unique_points(points, tol=1e-4):
    uniq = []
    for p in points:
        if not any(np.linalg.norm(p - q) < tol for q in uniq):
            uniq.append(p)
    return uniq


def find_all_minima(model, xlim=(-2, 2), ylim=(-2, 2), ngrid=17):
    xs = np.linspace(xlim[0], xlim[1], ngrid)
    ys = np.linspace(ylim[0], ylim[1], ngrid)

    candidates = []
    for x0 in xs:
        for y0 in ys:
            try:
                p, _ = refine_stationary_point(model, np.array([x0, y0]))
                is_min, _ = classify_point(model, p)
                if is_min:
                    candidates.append(p)
            except Exception:
                pass

    minima = unique_points(candidates, tol=1e-4)

    result = []
    for p in minima:
        val = model.V(p)
        result.append((p, val))

    result.sort(key=lambda item: item[1])
    return result


def choose_closest_false_vacuum(minima):
    """
    True vacuum = global minimum.
    False vacuum = local minimum with smallest Euclidean distance
    to the true vacuum among the remaining minima.
    """
    if len(minima) < 2:
        raise RuntimeError("Need at least two minima for tunneling.")

    true_vacuum, v_true = minima[0]

    candidates = []
    for p, val in minima[1:]:
        dist = np.linalg.norm(p - true_vacuum)
        candidates.append((dist, p, val))

    candidates.sort(key=lambda t: t[0])
    dist, false_vacuum, v_false = candidates[0]

    return true_vacuum, v_true, false_vacuum, v_false, dist


def same_point(p, q, tol=5e-2):
    return np.linalg.norm(np.asarray(p) - np.asarray(q)) < tol


def scan_action_vs_kappa2(
    kappa1=0.7,
    rho=0.5,
    gamma=0.2,
    kappa2_min=0.5,
    kappa2_max=1.5,
    n_kappa2=41,
    xlim=(-2, 2),
    ylim=(-2, 2),
    ngrid=17
):
    kappa2_values = np.linspace(kappa2_min, kappa2_max, n_kappa2)

    results = []

    for kappa2 in kappa2_values:
        print(f"\n--- kappa2 = {kappa2:.6f} ---")
        model = TwoDimColemanPotential(
            kappa1=kappa1,
            rho=rho,
            kappa2=kappa2,
            gamma=gamma
        )

        minima = find_all_minima(model, xlim=xlim, ylim=ylim, ngrid=ngrid)
        nmin = len(minima)

        print(f"Number of minima = {nmin}")
        for i, (p, val) in enumerate(minima, start=1):
            print(f"  minimum {i}: ({p[0]: .6f}, {p[1]: .6f}), V = {val: .12f}")

        if nmin < 2:
            print("  Skipping: fewer than two minima.")
            results.append({
                "kappa2": kappa2,
                "nmin": nmin,
                "action": np.nan,
                "tv": None,
                "fv": None,
                "v_true": np.nan,
                "v_false": np.nan
            })
            continue

        try:
            true_vacuum, v_true, false_vacuum, v_false, dist = choose_closest_false_vacuum(minima)

            print(f"  True vacuum : ({true_vacuum[0]: .6f}, {true_vacuum[1]: .6f}), V = {v_true: .12f}")
            print(f"  False vacuum: ({false_vacuum[0]: .6f}, {false_vacuum[1]: .6f}), V = {v_false: .12f}")
            print(f"  Delta V     = {v_false - v_true: .12f}")
            print(f"  Distance    = {dist: .6f}")

            init_path = [true_vacuum, false_vacuum]
            Y = pd.fullTunneling(init_path, model.V, model.dV)
            action = Y.action

            print(f"  Action      = {action: .12f}")

            results.append({
                "kappa2": kappa2,
                "nmin": nmin,
                "action": action,
                "tv": np.array(true_vacuum),
                "fv": np.array(false_vacuum),
                "v_true": v_true,
                "v_false": v_false
            })

        except Exception as exc:
            print(f"  Solver failed: {exc}")
            results.append({
                "kappa2": kappa2,
                "nmin": nmin,
                "action": np.nan,
                "tv": None,
                "fv": None,
                "v_true": np.nan,
                "v_false": np.nan
            })

    return results


def split_into_segments(results, point_tol=5e-2):
    """
    Start a new curve whenever:
      1) number of minima changes, or
      2) chosen true vacuum changes noticeably, or
      3) chosen false vacuum changes noticeably, or
      4) action is NaN / invalid.
    """
    segments = []
    current = []

    prev = None
    for r in results:
        valid = np.isfinite(r["action"]) and (r["tv"] is not None) and (r["fv"] is not None)

        if not valid:
            if current:
                segments.append(current)
                current = []
            prev = None
            continue

        if prev is None:
            current = [r]
            prev = r
            continue

        changed = False

        if r["nmin"] != prev["nmin"]:
            changed = True
        elif not same_point(r["tv"], prev["tv"], tol=point_tol):
            changed = True
        elif not same_point(r["fv"], prev["fv"], tol=point_tol):
            changed = True

        if changed:
            if current:
                segments.append(current)
            current = [r]
        else:
            current.append(r)

        prev = r

    if current:
        segments.append(current)

    return segments


def plot_action_vs_kappa2(results):
    segments = split_into_segments(results, point_tol=5e-2)

    plt.figure(figsize=(9, 6))

    for i, seg in enumerate(segments, start=1):
        kappa2_values = [r["kappa2"] for r in seg]
        actions = [r["action"] for r in seg]
        nmin = seg[0]["nmin"]

        label = f"Segment {i}: {nmin} minima"
        plt.plot(kappa2_values, actions, marker='o', linewidth=2, label=label)

    plt.xlabel(r"$\kappa_2$")
    plt.ylabel("B")
#    plt.title(r"Action vs $\kappa_2$ for fixed $\kappa_1=0.7,\ \rho=0.5,\ \gamma=0.2$")
    plt.grid(True, alpha=0.3)
    plt.legend(fontsize='small')
    plt.tight_layout()
    plt.savefig("action_vs_kappa1.png", dpi=300, bbox_inches="tight")
    plt.show()


def main():
    start = time.perf_counter()

    results = scan_action_vs_kappa2(
        kappa1=0.7,
        rho=0.5,
        gamma=0.2,
        kappa2_min=0.5,
        kappa2_max=1.5,
        n_kappa2=41,   # increase for smoother curves
        xlim=(-2, 2),
        ylim=(-2, 2),
        ngrid=17
    )

    print("\n================ SUMMARY ================")
    for r in results:
        if np.isfinite(r["action"]):
            print(
                f"kappa2={r['kappa2']:.6f}, "
                f"nmin={r['nmin']}, "
                f"action={r['action']:.10f}, "
                f"TV=({r['tv'][0]:.6f},{r['tv'][1]:.6f}), "
                f"FV=({r['fv'][0]:.6f},{r['fv'][1]:.6f})"
            )
        else:
            print(
                f"kappa2={r['kappa2']:.6f}, "
                f"nmin={r['nmin']}, action=NaN"
            )

    plot_action_vs_kappa2(results)

    end = time.perf_counter()
    print(f"\nRuntime: {end - start:.6f} seconds")


if __name__ == "__main__":
    main()
# Out:
# --- kappa2 = 0.500000 ---
# Number of minima = 4
#   minimum 1: (-1.037833, -0.956682), V = -1.708956900177
#   minimum 2: (-1.050941,  0.787659), V = -1.268737988489
#   minimum 3: ( 0.831060, -0.993804), V = -0.384516192109
#   minimum 4: ( 0.850659,  0.840576), V =  0.077299417076
#   True vacuum : (-1.037833, -0.956682), V = -1.708956900177
#   False vacuum: (-1.050941,  0.787659), V = -1.268737988489
#   Delta V     =  0.440218911688
#   Distance    =  1.744390
# Path deformation converged. 9 steps. fRatio = 1.41017e-02
# Path deformation converged. 1 steps. fRatio = 1.55265e-03
#   Action      =  53.589074335803
#
# --- kappa2 = 0.525000 ---
# Number of minima = 4
#   minimum 1: (-1.037556, -0.959910), V = -1.733435631663
#   minimum 2: (-1.051356,  0.781679), V = -1.271429460978
#   minimum 3: ( 0.830632, -0.996834), V = -0.409457705839
#   minimum 4: ( 0.851247,  0.835449), V =  0.075274682901
#   True vacuum : (-1.037556, -0.959910), V = -1.733435631663
#   False vacuum: (-1.051356,  0.781679), V = -1.271429460978
#   Delta V     =  0.462006170684
#   Distance    =  1.741644
# Path deformation converged. 9 steps. fRatio = 1.56997e-02
# Path deformation converged. 1 steps. fRatio = 1.46732e-03
#   Action      =  47.233837849974
#
# --- kappa2 = 0.550000 ---
# Number of minima = 4
#   minimum 1: (-1.037281, -0.963108), V = -1.757954522629
#   minimum 2: (-1.051779,  0.775535), V = -1.274196692015
#   minimum 3: ( 0.830206, -0.999837), V = -0.434436923250
#   minimum 4: ( 0.851844,  0.830212), V =  0.073185178844
#   True vacuum : (-1.037281, -0.963108), V = -1.757954522629
#   False vacuum: (-1.051779,  0.775535), V = -1.274196692015
#   Delta V     =  0.483757830615
#   Distance    =  1.738704
# Path deformation converged. 9 steps. fRatio = 1.74293e-02
# Path deformation converged. 1 steps. fRatio = 1.67648e-03
#   Action      =  41.859515214616
#
# --- kappa2 = 0.575000 ---
# Number of minima = 4
#   minimum 1: (-1.037008, -0.966276), V = -1.782513202689
#   minimum 2: (-1.052211,  0.769215), V = -1.277041810068
#   minimum 3: ( 0.829781, -1.002816), V = -0.459453527609
#   minimum 4: ( 0.852449,  0.824860), V =  0.071029503090
#   True vacuum : (-1.037008, -0.966276), V = -1.782513202689
#   False vacuum: (-1.052211,  0.769215), V = -1.277041810068
#   Delta V     =  0.505471392621
#   Distance    =  1.735558
# Path deformation converged. 9 steps. fRatio = 1.93132e-02
# Path deformation converged. 1 steps. fRatio = 2.20783e-03
#   Action      =  37.360989714366
#
# --- kappa2 = 0.600000 ---
# Number of minima = 4
#   minimum 1: (-1.036736, -0.969416), V = -1.807111310339
#   minimum 2: (-1.052652,  0.762703), V = -1.279967114395
#   minimum 3: ( 0.829359, -1.005769), V = -0.484507209128
#   minimum 4: ( 0.853064,  0.819385), V =  0.068806168473
#   True vacuum : (-1.036736, -0.969416), V = -1.807111310339
#   False vacuum: (-1.052652,  0.762703), V = -1.279967114395
#   Delta V     =  0.527144195943
#   Distance    =  1.732192
# Path deformation converged. 11 steps. fRatio = 1.68170e-02
# Path deformation converged. 1 steps. fRatio = 1.24826e-02
#   Action      =  33.339768441623
#
# --- kappa2 = 0.625000 ---
# Number of minima = 4
#   minimum 1: (-1.036466, -0.972528), V = -1.831748492618
#   minimum 2: (-1.053102,  0.755983), V = -1.282975098889
#   minimum 3: ( 0.828939, -1.008699), V = -0.509597664709
#   minimum 4: ( 0.853688,  0.813780), V =  0.066513593561
#   True vacuum : (-1.036466, -0.972528), V = -1.831748492618
#   False vacuum: (-1.053102,  0.755983), V = -1.282975098889
#   Delta V     =  0.548773393729
#   Distance    =  1.728592
# Path deformation converged. 11 steps. fRatio = 1.87239e-02
# Path deformation converged. 1 steps. fRatio = 1.39452e-02
#   Action      =  29.717521862378
#
# --- kappa2 = 0.650000 ---
# Number of minima = 4
#   minimum 1: (-1.036197, -0.975613), V = -1.856424404785
#   minimum 2: (-1.053564,  0.749036), V = -1.286068480856
#   minimum 3: ( 0.828520, -1.011606), V = -0.534724597722
#   minimum 4: ( 0.854323,  0.808036), V =  0.064150092387
#   True vacuum : (-1.036197, -0.975613), V = -1.856424404785
#   False vacuum: (-1.053564,  0.749036), V = -1.286068480856
#   Delta V     =  0.570355923929
#   Distance    =  1.724737
# Path deformation converged. 12 steps. fRatio = 1.45565e-02
# Path deformation converged. 1 steps. fRatio = 9.23893e-03
#   Action      =  26.433576021190
#
# --- kappa2 = 0.675000 ---
# Number of minima = 4
#   minimum 1: (-1.035930, -0.978671), V = -1.881138710002
#   minimum 2: (-1.054038,  0.741839), V = -1.289250236103
#   minimum 3: ( 0.828103, -1.014489), V = -0.559887717771
#   minimum 4: ( 0.854968,  0.802142), V =  0.061713862541
#   True vacuum : (-1.035930, -0.978671), V = -1.881138710002
#   False vacuum: (-1.054038,  0.741839), V = -1.289250236103
#   Delta V     =  0.591888473899
#   Distance    =  1.720606
# Path deformation converged. 12 steps. fRatio = 1.64355e-02
# Path deformation converged. 1 steps. fRatio = 1.05730e-02
#   Action      =  23.504325498971
#
# --- kappa2 = 0.700000 ---
# Number of minima = 4
#   minimum 1: (-1.035664, -0.981703), V = -1.905891079053
#   minimum 2: (-1.054525,  0.734367), V = -1.292523642244
#   minimum 3: ( 0.827688, -1.017350), V = -0.585086740491
#   minimum 4: ( 0.855626,  0.796088), V =  0.059202971285
#   True vacuum : (-1.035664, -0.981703), V = -1.905891079053
#   False vacuum: (-1.054525,  0.734367), V = -1.292523642244
#   Delta V     =  0.613367436809
#   Distance    =  1.716174
# Path deformation converged. 10 steps. fRatio = 5.54949e-03
# Path deformation converged. 1 steps. fRatio = 2.33049e-03
#   Action      =  20.884169268146
#
# --- kappa2 = 0.725000 ---
# Number of minima = 4
#   minimum 1: (-1.035399, -0.984710), V = -1.930681190057
#   minimum 2: (-1.055026,  0.726588), V = -1.295892332860
#   minimum 3: ( 0.827275, -1.020189), V = -0.610321387341
#   minimum 4: ( 0.856296,  0.789861), V =  0.056615339239
#   True vacuum : (-1.035399, -0.984710), V = -1.930681190057
#   False vacuum: (-1.055026,  0.726588), V = -1.295892332860
#   Delta V     =  0.634788857197
#   Distance    =  1.711411
# Path deformation converged. 10 steps. fRatio = 6.75849e-03
# Path deformation converged. 1 steps. fRatio = 2.41584e-03
#   Action      =  18.521503442748
#
# --- kappa2 = 0.750000 ---
# Number of minima = 4
#   minimum 1: (-1.035136, -0.987692), V = -1.955508728209
#   minimum 2: (-1.055544,  0.718466), V = -1.299360366299
#   minimum 3: ( 0.826863, -1.023007), V = -0.635591385414
#   minimum 4: ( 0.856981,  0.783448), V =  0.053948721065
#   True vacuum : (-1.035136, -0.987692), V = -1.955508728209
#   False vacuum: (-1.055544,  0.718466), V = -1.299360366299
#   Delta V     =  0.656148361910
#   Distance    =  1.706279
# Path deformation converged. 10 steps. fRatio = 8.25378e-03
# Path deformation converged. 1 steps. fRatio = 2.43310e-03
#   Action      =  16.373512443229
#
# --- kappa2 = 0.775000 ---
# Number of minima = 4
#   minimum 1: (-1.034874, -0.990649), V = -1.980373385528
#   minimum 2: (-1.056079,  0.709954), V = -1.302932314613
#   minimum 3: ( 0.826453, -1.025803), V = -0.660896467253
#   minimum 4: ( 0.857680,  0.776831), V =  0.051200682400
#   True vacuum : (-1.034874, -0.990649), V = -1.980373385528
#   False vacuum: (-1.056079,  0.709954), V = -1.302932314613
#   Delta V     =  0.677441070915
#   Distance    =  1.700735
# Path deformation converged. 10 steps. fRatio = 1.01473e-02
# Path deformation converged. 1 steps. fRatio = 2.36171e-03
#   Action      =  14.417664673660
#
# --- kappa2 = 0.800000 ---
# Number of minima = 4
#   minimum 1: (-1.034613, -0.993583), V = -2.005274860619
#   minimum 2: (-1.056636,  0.700996), V = -1.306613380920
#   minimum 3: ( 0.826045, -1.028578), V = -0.686236370671
#   minimum 4: ( 0.858395,  0.769993), V =  0.048368572051
#   True vacuum : (-1.034613, -0.993583), V = -2.005274860619
#   False vacuum: (-1.056636,  0.700996), V = -1.306613380920
#   Delta V     =  0.698661479699
#   Distance    =  1.694722
# Path deformation converged. 10 steps. fRatio = 1.25440e-02
# Path deformation converged. 1 steps. fRatio = 2.17992e-03
#   Action      =  12.700990473140
#
# --- kappa2 = 0.825000 ---
# Number of minima = 4
#   minimum 1: (-1.034354, -0.996493), V = -2.030212858446
#   minimum 2: (-1.057217,  0.691522), V = -1.310409558045
#   minimum 3: ( 0.825638, -1.031333), V = -0.711610838591
#   minimum 4: ( 0.859129,  0.762911), V =  0.045449488120
#   True vacuum : (-1.034354, -0.996493), V = -2.030212858446
#   False vacuum: (-1.057217,  0.691522), V = -1.310409558045
#   Delta V     =  0.719803300402
#   Distance    =  1.688170
# Path deformation converged. 10 steps. fRatio = 1.56181e-02
# Path deformation converged. 1 steps. fRatio = 1.77339e-03
#   Action      =  11.082276271094
#
# --- kappa2 = 0.850000 ---
# Number of minima = 4
#   minimum 1: (-1.034096, -0.999380), V = -2.055187090115
#   minimum 2: (-1.057827,  0.681440), V = -1.314327849224
#   minimum 3: ( 0.825233, -1.034068), V = -0.737019618878
#   minimum 4: ( 0.859882,  0.755561), V =  0.042440236236
#   True vacuum : (-1.034096, -0.999380), V = -2.055187090115
#   False vacuum: (-1.057827,  0.681440), V = -1.314327849224
#   Delta V     =  0.740859240890
#   Distance    =  1.680988
# Path deformation converged. 10 steps. fRatio = 1.95684e-02
# Path deformation converged. 1 steps. fRatio = 1.04976e-03
#   Action      =  9.593026937483
#
# --- kappa2 = 0.875000 ---
# Number of minima = 4
#   minimum 1: (-1.033839, -1.002245), V = -2.080197272666
#   minimum 2: (-1.058470,  0.670627), V = -1.318376586110
#   minimum 3: ( 0.824829, -1.036784), V = -0.762462464189
#   minimum 4: ( 0.860656,  0.747913), V =  0.039337277381
#   True vacuum : (-1.033839, -1.002245), V = -2.080197272666
#   False vacuum: (-1.058470,  0.670627), V = -1.318376586110
#   Delta V     =  0.761820686556
#   Distance    =  1.673054
# Path deformation converged. 12 steps. fRatio = 1.94669e-02
# Path deformation converged. 1 steps. fRatio = 1.47715e-02
#   Action      =  8.207614773960
#
# --- kappa2 = 0.900000 ---
# Number of minima = 4
#   minimum 1: (-1.033583, -1.005088), V = -2.105243128882
#   minimum 2: (-1.059155,  0.658913), V = -1.322565907348
#   minimum 3: ( 0.824427, -1.039480), V = -0.787939131825
#   minimum 4: ( 0.861456,  0.739930), V =  0.036136661695
#   True vacuum : (-1.033583, -1.005088), V = -2.105243128882
#   False vacuum: (-1.059155,  0.658913), V = -1.322565907348
#   Delta V     =  0.782677221534
#   Distance    =  1.664198
# Path deformation converged. 11 steps. fRatio = 7.86068e-04
# Path deformation converged. 1 steps. fRatio = 1.28193e-03
#   Action      =  6.872805351244
#
# --- kappa2 = 0.925000 ---
# Number of minima = 4
#   minimum 1: (-1.033328, -1.007910), V = -2.130324387095
#   minimum 2: (-1.059893,  0.646051), V = -1.326908520169
#   minimum 3: ( 0.824026, -1.042157), V = -0.813449383593
#   minimum 4: ( 0.862282,  0.731568), V =  0.032833943035
#   True vacuum : (-1.033328, -1.007910), V = -2.130324387095
#   False vacuum: (-1.059893,  0.646051), V = -1.326908520169
#   Delta V     =  0.803415866926
#   Distance    =  1.654173
# Path deformation converged. 11 steps. fRatio = 4.17846e-03
# Path deformation converged. 1 steps. fRatio = 6.98615e-04
#   Action      =  5.633531380201
#
# --- kappa2 = 0.950000 ---
# Number of minima = 4
#   minimum 1: (-1.033075, -1.010710), V = -2.155440781009
#   minimum 2: (-1.060701,  0.631652), V = -1.331421005870
#   minimum 3: ( 0.823627, -1.044816), V = -0.838992985666
#   minimum 4: ( 0.863141,  0.722774), V =  0.029424066421
#   True vacuum : (-1.033075, -1.010710), V = -2.155440781009
#   False vacuum: (-1.060701,  0.631652), V = -1.331421005870
#   Delta V     =  0.824019775139
#   Distance    =  1.642595
# Path deformation converged. 11 steps. fRatio = 7.77158e-03
# Path deformation converged. 1 steps. fRatio = 5.86607e-04
#   Action      =  4.462852719598
#
# --- kappa2 = 0.975000 ---
# Number of minima = 4
#   minimum 1: (-1.032823, -1.013490), V = -2.180592049531
#   minimum 2: (-1.061610,  0.615052), V = -1.336126304621
#   minimum 3: ( 0.823229, -1.047457), V = -0.864569708456
#   minimum 4: ( 0.864035,  0.713480), V =  0.025901216203
#   True vacuum : (-1.032823, -1.013490), V = -2.180592049531
#   False vacuum: (-1.061610,  0.615052), V = -1.336126304621
#   Delta V     =  0.844465744910
#   Distance    =  1.628796
# Path deformation converged. 11 steps. fRatio = 1.05732e-02
# Path deformation converged. 1 steps. fRatio = 7.67792e-04
#   Action      =  3.342964206230
#
# --- kappa2 = 1.000000 ---
# Number of minima = 4
#   minimum 1: (-1.032571, -1.016249), V = -2.205777936603
#   minimum 2: (-1.062680,  0.594895), V = -1.341059271373
#   minimum 3: ( 0.822833, -1.050079), V = -0.890179326491
#   minimum 4: ( 0.864972,  0.703596), V =  0.022258605333
#   True vacuum : (-1.032571, -1.016249), V = -2.205777936603
#   False vacuum: (-1.062680,  0.594895), V = -1.341059271373
#   Delta V     =  0.864718665230
#   Distance    =  1.611426
# Path deformation converged. 11 steps. fRatio = 1.08941e-02
# Path deformation converged. 1 steps. fRatio = 8.11925e-04
#   Action      =  2.249242868009
#
# --- kappa2 = 1.025000 ---
# Number of minima = 4
#   minimum 1: (-1.032321, -1.018988), V = -2.230998191047
#   minimum 2: (-1.064083,  0.567345), V = -1.346283346174
#   minimum 3: ( 0.822437, -1.052684), V = -0.915821618295
#   minimum 4: ( 0.865960,  0.693005), V =  0.018488172648
#   True vacuum : (-1.032321, -1.018988), V = -2.230998191047
#   False vacuum: (-1.064083,  0.567345), V = -1.346283346174
#   Delta V     =  0.884714844873
#   Distance    =  1.586651
# Path deformation converged. 11 steps. fRatio = 3.26058e-03
# Path deformation converged. 1 steps. fRatio = 1.34311e-03
#   Action      =  1.132804240149
#
# --- kappa2 = 1.050000 ---
# Number of minima = 3
#   minimum 1: (-1.032072, -1.021708), V = -2.256252566417
#   minimum 2: ( 0.822044, -1.055272), V = -0.941496366274
#   minimum 3: ( 0.867010,  0.681546), V =  0.014580128974
#   True vacuum : (-1.032072, -1.021708), V = -2.256252566417
#   False vacuum: ( 0.822044, -1.055272), V = -0.941496366274
#   Delta V     =  1.314756200143
#   Distance    =  1.854420
# Path deformation converged. 16 steps. fRatio = 1.81020e-02
# Path deformation converged. 1 steps. fRatio = 2.38252e-02
#   Action      =  28.326717038012
#
# --- kappa2 = 1.075000 ---
# Number of minima = 3
#   minimum 1: (-1.031824, -1.024409), V = -2.281540820851
#   minimum 2: ( 0.821651, -1.057843), V = -0.967203356603
#   minimum 3: ( 0.868139,  0.668982), V =  0.010522238295
#   True vacuum : (-1.031824, -1.024409), V = -2.281540820851
#   False vacuum: ( 0.821651, -1.057843), V = -0.967203356603
#   Delta V     =  1.314337464248
#   Distance    =  1.853777
# Path deformation converged. 16 steps. fRatio = 1.79114e-02
# Path deformation converged. 1 steps. fRatio = 2.35704e-02
#   Action      =  28.246856962491
#
# --- kappa2 = 1.100000 ---
# Number of minima = 3
#   minimum 1: (-1.031577, -1.027091), V = -2.306862716938
#   minimum 2: ( 0.821260, -1.060398), V = -0.992942379127
#   minimum 3: ( 0.869373,  0.654949), V =  0.006298593576
#   True vacuum : (-1.031577, -1.027091), V = -2.306862716938
#   False vacuum: ( 0.821260, -1.060398), V = -0.992942379127
#   Delta V     =  1.313920337811
#   Distance    =  1.853137
# Path deformation converged. 16 steps. fRatio = 1.77232e-02
# Path deformation converged. 1 steps. fRatio = 2.31949e-02
#   Action      =  28.280795011817
#
# --- kappa2 = 1.125000 ---
# Number of minima = 3
#   minimum 1: (-1.031331, -1.029755), V = -2.332218021581
#   minimum 2: ( 0.820871, -1.062935), V = -1.018713227251
#   minimum 3: ( 0.870756,  0.638822), V =  0.001887308636
#   True vacuum : (-1.031331, -1.029755), V = -2.332218021581
#   False vacuum: ( 0.820871, -1.062935), V = -1.018713227251
#   Delta V     =  1.313504794330
#   Distance    =  1.852499
# Path deformation converged. 16 steps. fRatio = 1.75373e-02
# Path deformation converged. 1 steps. fRatio = 2.29378e-02
#   Action      =  28.204804941937
#
# --- kappa2 = 1.150000 ---
# Number of minima = 3
#   minimum 1: (-1.031086, -1.032400), V = -2.357606505874
#   minimum 2: ( 0.820482, -1.065457), V = -1.044515697849
#   minimum 3: ( 0.872375,  0.619353), V = -0.002744564570
#   True vacuum : (-1.031086, -1.032400), V = -2.357606505874
#   False vacuum: ( 0.820482, -1.065457), V = -1.044515697849
#   Delta V     =  1.313090808025
#   Distance    =  1.851863
# Path deformation converged. 16 steps. fRatio = 1.73544e-02
# Path deformation converged. 1 steps. fRatio = 2.26878e-02
#   Action      =  28.128907474254
#
# --- kappa2 = 1.175000 ---
# Number of minima = 3
#   minimum 1: (-1.030842, -1.035027), V = -2.383027944981
#   minimum 2: ( 0.820095, -1.067963), V = -1.070349591169
#   minimum 3: ( 0.874470,  0.593140), V = -0.007655818134
#   True vacuum : (-1.030842, -1.035027), V = -2.383027944981
#   False vacuum: ( 0.820095, -1.067963), V = -1.070349591169
#   Delta V     =  1.312678353812
#   Distance    =  1.851230
# Path deformation converged. 16 steps. fRatio = 1.71729e-02
# Path deformation converged. 1 steps. fRatio = 2.24432e-02
#   Action      =  28.053342901741
#
# --- kappa2 = 1.200000 ---
# Number of minima = 2
#   minimum 1: (-1.030599, -1.037637), V = -2.408482118015
#   minimum 2: ( 0.819709, -1.070453), V = -1.096214710738
#   True vacuum : (-1.030599, -1.037637), V = -2.408482118015
#   False vacuum: ( 0.819709, -1.070453), V = -1.096214710738
#   Delta V     =  1.312267407277
#   Distance    =  1.850599
# Path deformation converged. 16 steps. fRatio = 1.69940e-02
# Path deformation converged. 1 steps. fRatio = 2.21985e-02
#   Action      =  27.978331368973
#
# --- kappa2 = 1.225000 ---
# Number of minima = 2
#   minimum 1: (-1.030357, -1.040230), V = -2.433968807930
#   minimum 2: ( 0.819324, -1.072928), V = -1.122110863282
#   True vacuum : (-1.030357, -1.040230), V = -2.433968807930
#   False vacuum: ( 0.819324, -1.072928), V = -1.122110863282
#   Delta V     =  1.311857944649
#   Distance    =  1.849970
# Path deformation converged. 16 steps. fRatio = 1.68181e-02
# Path deformation converged. 1 steps. fRatio = 2.19598e-02
#   Action      =  27.903443615212
#
# --- kappa2 = 1.250000 ---
# Number of minima = 2
#   minimum 1: (-1.030116, -1.042806), V = -2.459487801412
#   minimum 2: ( 0.818940, -1.075388), V = -1.148037858634
#   True vacuum : (-1.030116, -1.042806), V = -2.459487801412
#   False vacuum: ( 0.818940, -1.075388), V = -1.148037858634
#   Delta V     =  1.311449942778
#   Distance    =  1.849344
# Path deformation converged. 16 steps. fRatio = 1.66420e-02
# Path deformation converged. 1 steps. fRatio = 2.17211e-02
#   Action      =  27.829296848355
#
# --- kappa2 = 1.275000 ---
# Number of minima = 2
#   minimum 1: (-1.029876, -1.045365), V = -2.485038888773
#   minimum 2: ( 0.818558, -1.077833), V = -1.173995509660
#   True vacuum : (-1.029876, -1.045365), V = -2.485038888773
#   False vacuum: ( 0.818558, -1.077833), V = -1.173995509660
#   Delta V     =  1.311043379113
#   Distance    =  1.848719
# Path deformation converged. 16 steps. fRatio = 1.65111e-02
# Path deformation converged. 1 steps. fRatio = 2.14853e-02
#   Action      =  27.755414144331
#
# --- kappa2 = 1.300000 ---
# Number of minima = 2
#   minimum 1: (-1.029637, -1.047908), V = -2.510621863857
#   minimum 2: ( 0.818176, -1.080264), V = -1.199983632179
#   True vacuum : (-1.029637, -1.047908), V = -2.510621863857
#   False vacuum: ( 0.818176, -1.080264), V = -1.199983632179
#   Delta V     =  1.310638231678
#   Distance    =  1.848096
# Path deformation converged. 16 steps. fRatio = 1.63969e-02
# Path deformation converged. 1 steps. fRatio = 2.12542e-02
#   Action      =  27.681769247531
#
# --- kappa2 = 1.325000 ---
# Number of minima = 2
#   minimum 1: (-1.029398, -1.050435), V = -2.536236523938
#   minimum 2: ( 0.817796, -1.082680), V = -1.226002044883
#   True vacuum : (-1.029398, -1.050435), V = -2.536236523938
#   False vacuum: ( 0.817796, -1.082680), V = -1.226002044883
#   Delta V     =  1.310234479055
#   Distance    =  1.847476
# Path deformation converged. 16 steps. fRatio = 1.62631e-02
# Path deformation converged. 1 steps. fRatio = 2.10727e-02
#   Action      =  27.608607299619
#
# --- kappa2 = 1.350000 ---
# Number of minima = 2
#   minimum 1: (-1.029161, -1.052946), V = -2.561882669631
#   minimum 2: ( 0.817417, -1.085082), V = -1.252050569272
#   True vacuum : (-1.029161, -1.052946), V = -2.561882669631
#   False vacuum: ( 0.817417, -1.085082), V = -1.252050569272
#   Delta V     =  1.309832100360
#   Distance    =  1.846858
# Path deformation converged. 12 steps. fRatio = 1.79746e-02
# Path deformation converged. 1 steps. fRatio = 5.04592e-02
#   Action      =  27.522321222546
#
# --- kappa2 = 1.375000 ---
# Number of minima = 2
#   minimum 1: (-1.028924, -1.055441), V = -2.587560104805
#   minimum 2: ( 0.817039, -1.087470), V = -1.278129029578
#   True vacuum : (-1.028924, -1.055441), V = -2.587560104805
#   False vacuum: ( 0.817039, -1.087470), V = -1.278129029578
#   Delta V     =  1.309431075226
#   Distance    =  1.846241
# Path deformation converged. 12 steps. fRatio = 1.77890e-02
# Path deformation converged. 1 steps. fRatio = 5.17497e-02
#   Action      =  27.449721625133
#
# --- kappa2 = 1.400000 ---
# Number of minima = 2
#   minimum 1: (-1.028688, -1.057921), V = -2.613268636490
#   minimum 2: ( 0.816662, -1.089844), V = -1.304237252702
#   True vacuum : (-1.028688, -1.057921), V = -2.613268636490
#   False vacuum: ( 0.816662, -1.089844), V = -1.304237252702
#   Delta V     =  1.309031383788
#   Distance    =  1.845627
# Path deformation converged. 12 steps. fRatio = 1.76047e-02
# Path deformation converged. 1 steps. fRatio = 5.29876e-02
#   Action      =  27.377592853096
#
# --- kappa2 = 1.425000 ---
# Number of minima = 2
#   minimum 1: (-1.028453, -1.060386), V = -2.639008074805
#   minimum 2: ( 0.816286, -1.092204), V = -1.330375068143
#   True vacuum : (-1.028453, -1.060386), V = -2.639008074805
#   False vacuum: ( 0.816286, -1.092204), V = -1.330375068143
#   Delta V     =  1.308633006662
#   Distance    =  1.845014
# Path deformation converged. 12 steps. fRatio = 1.74229e-02
# Path deformation converged. 1 steps. fRatio = 5.42166e-02
#   Action      =  27.305733090154
#
# --- kappa2 = 1.450000 ---
# Number of minima = 2
#   minimum 1: (-1.028219, -1.062837), V = -2.664778232868
#   minimum 2: ( 0.815912, -1.094552), V = -1.356542307940
#   True vacuum : (-1.028219, -1.062837), V = -2.664778232868
#   False vacuum: ( 0.815912, -1.094552), V = -1.356542307940
#   Delta V     =  1.308235924928
#   Distance    =  1.844404
# Path deformation converged. 12 steps. fRatio = 1.72428e-02
# Path deformation converged. 1 steps. fRatio = 5.54172e-02
#   Action      =  27.234109951028
#
# --- kappa2 = 1.475000 ---
# Number of minima = 2
#   minimum 1: (-1.027986, -1.065272), V = -2.690578926729
#   minimum 2: ( 0.815538, -1.096886), V = -1.382738806609
#   True vacuum : (-1.027986, -1.065272), V = -2.690578926729
#   False vacuum: ( 0.815538, -1.096886), V = -1.382738806609
#   Delta V     =  1.307840120120
#   Distance    =  1.843795
# Path deformation converged. 12 steps. fRatio = 1.70637e-02
# Path deformation converged. 1 steps. fRatio = 5.65564e-02
#   Action      =  27.163322899545
#
# --- kappa2 = 1.500000 ---
# Number of minima = 2
#   minimum 1: (-1.027754, -1.067693), V = -2.716409975286
#   minimum 2: ( 0.815165, -1.099207), V = -1.408964401083
#   True vacuum : (-1.027754, -1.067693), V = -2.716409975286
#   False vacuum: ( 0.815165, -1.099207), V = -1.408964401083
#   Delta V     =  1.307445574204
#   Distance    =  1.843188
# Path deformation converged. 12 steps. fRatio = 1.68872e-02
# Path deformation converged. 1 steps. fRatio = 5.77040e-02
#   Action      =  27.092436596001
#
# ================ SUMMARY ================
# kappa2=0.500000, nmin=4, action=53.5890743358, TV=(-1.037833,-0.956682), FV=(-1.050941,0.787659)
# kappa2=0.525000, nmin=4, action=47.2338378500, TV=(-1.037556,-0.959910), FV=(-1.051356,0.781679)
# kappa2=0.550000, nmin=4, action=41.8595152146, TV=(-1.037281,-0.963108), FV=(-1.051779,0.775535)
# kappa2=0.575000, nmin=4, action=37.3609897144, TV=(-1.037008,-0.966276), FV=(-1.052211,0.769215)
# kappa2=0.600000, nmin=4, action=33.3397684416, TV=(-1.036736,-0.969416), FV=(-1.052652,0.762703)
# kappa2=0.625000, nmin=4, action=29.7175218624, TV=(-1.036466,-0.972528), FV=(-1.053102,0.755983)
# kappa2=0.650000, nmin=4, action=26.4335760212, TV=(-1.036197,-0.975613), FV=(-1.053564,0.749036)
# kappa2=0.675000, nmin=4, action=23.5043254990, TV=(-1.035930,-0.978671), FV=(-1.054038,0.741839)
# kappa2=0.700000, nmin=4, action=20.8841692681, TV=(-1.035664,-0.981703), FV=(-1.054525,0.734367)
# kappa2=0.725000, nmin=4, action=18.5215034427, TV=(-1.035399,-0.984710), FV=(-1.055026,0.726588)
# kappa2=0.750000, nmin=4, action=16.3735124432, TV=(-1.035136,-0.987692), FV=(-1.055544,0.718466)
# kappa2=0.775000, nmin=4, action=14.4176646737, TV=(-1.034874,-0.990649), FV=(-1.056079,0.709954)
# kappa2=0.800000, nmin=4, action=12.7009904731, TV=(-1.034613,-0.993583), FV=(-1.056636,0.700996)
# kappa2=0.825000, nmin=4, action=11.0822762711, TV=(-1.034354,-0.996493), FV=(-1.057217,0.691522)
# kappa2=0.850000, nmin=4, action=9.5930269375, TV=(-1.034096,-0.999380), FV=(-1.057827,0.681440)
# kappa2=0.875000, nmin=4, action=8.2076147740, TV=(-1.033839,-1.002245), FV=(-1.058470,0.670627)
# kappa2=0.900000, nmin=4, action=6.8728053512, TV=(-1.033583,-1.005088), FV=(-1.059155,0.658913)
# kappa2=0.925000, nmin=4, action=5.6335313802, TV=(-1.033328,-1.007910), FV=(-1.059893,0.646051)
# kappa2=0.950000, nmin=4, action=4.4628527196, TV=(-1.033075,-1.010710), FV=(-1.060701,0.631652)
# kappa2=0.975000, nmin=4, action=3.3429642062, TV=(-1.032823,-1.013490), FV=(-1.061610,0.615052)
# kappa2=1.000000, nmin=4, action=2.2492428680, TV=(-1.032571,-1.016249), FV=(-1.062680,0.594895)
# kappa2=1.025000, nmin=4, action=1.1328042401, TV=(-1.032321,-1.018988), FV=(-1.064083,0.567345)
# kappa2=1.050000, nmin=3, action=28.3267170380, TV=(-1.032072,-1.021708), FV=(0.822044,-1.055272)
# kappa2=1.075000, nmin=3, action=28.2468569625, TV=(-1.031824,-1.024409), FV=(0.821651,-1.057843)
# kappa2=1.100000, nmin=3, action=28.2807950118, TV=(-1.031577,-1.027091), FV=(0.821260,-1.060398)
# kappa2=1.125000, nmin=3, action=28.2048049419, TV=(-1.031331,-1.029755), FV=(0.820871,-1.062935)
# kappa2=1.150000, nmin=3, action=28.1289074743, TV=(-1.031086,-1.032400), FV=(0.820482,-1.065457)
# kappa2=1.175000, nmin=3, action=28.0533429017, TV=(-1.030842,-1.035027), FV=(0.820095,-1.067963)
# kappa2=1.200000, nmin=2, action=27.9783313690, TV=(-1.030599,-1.037637), FV=(0.819709,-1.070453)
# kappa2=1.225000, nmin=2, action=27.9034436152, TV=(-1.030357,-1.040230), FV=(0.819324,-1.072928)
# kappa2=1.250000, nmin=2, action=27.8292968484, TV=(-1.030116,-1.042806), FV=(0.818940,-1.075388)
# kappa2=1.275000, nmin=2, action=27.7554141443, TV=(-1.029876,-1.045365), FV=(0.818558,-1.077833)
# kappa2=1.300000, nmin=2, action=27.6817692475, TV=(-1.029637,-1.047908), FV=(0.818176,-1.080264)
# kappa2=1.325000, nmin=2, action=27.6086072996, TV=(-1.029398,-1.050435), FV=(0.817796,-1.082680)
# kappa2=1.350000, nmin=2, action=27.5223212225, TV=(-1.029161,-1.052946), FV=(0.817417,-1.085082)
# kappa2=1.375000, nmin=2, action=27.4497216251, TV=(-1.028924,-1.055441), FV=(0.817039,-1.087470)
# kappa2=1.400000, nmin=2, action=27.3775928531, TV=(-1.028688,-1.057921), FV=(0.816662,-1.089844)
# kappa2=1.425000, nmin=2, action=27.3057330902, TV=(-1.028453,-1.060386), FV=(0.816286,-1.092204)
# kappa2=1.450000, nmin=2, action=27.2341099510, TV=(-1.028219,-1.062837), FV=(0.815912,-1.094552)
# kappa2=1.475000, nmin=2, action=27.1633228995, TV=(-1.027986,-1.065272), FV=(0.815538,-1.096886)
# kappa2=1.500000, nmin=2, action=27.0924365960, TV=(-1.027754,-1.067693), FV=(0.815165,-1.099207)
# Runtime: 32.488194 seconds
